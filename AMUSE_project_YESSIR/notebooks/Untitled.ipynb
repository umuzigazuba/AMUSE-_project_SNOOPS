# %%
#%%
import os
os.chdir('../src')

from molecular_cloud_initialization import *
from plotters import *
from cluster_cloud_initialization import *
from time import time
from datetime import datetime
import socket


import numpy as np
import matplotlib.pyplot as plt
from amuse.community.fi.interface import Fi
from amuse.lab import Particles, nbody_system
from amuse.couple import bridge
from amuse.units import units
from amuse.community.bhtree.interface import Bhtree
from amuse.ext.sink import new_sink_particles
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       2 import os
#       3 os.chdir('../src')
# ----> 5 from molecular_cloud_initialization import *
#       6 from plotters import *
#       7 from cluster_cloud_initialization import *
#
# File ~/Desktop/AMUSE_project_YESSIR/AMUSE_project_YESSIR/src/molecular_cloud_initialization.py:7
#       4 from amuse.ext.molecular_cloud import molecular_cloud
#       5 from amuse.ext.evrard_test import body_centered_grid_unit_cube
# ----> 7 from amuse.community.fi.interface import Fi
#       9 from amuse.units import units
#      10 import numpy as np
#
# ModuleNotFoundError: No module named 'amuse.community.fi'

# %%
pip install amuse-fi
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting amuse-fi
#   Using cached amuse-fi-2023.11.0.tar.gz (8.3 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: amuse-framework in /home/s3805352/.local/lib/python3.10/site-packages (from amuse-fi) (2023.11.0)
# Requirement already satisfied: setuptools>=41.0.0 in /cm/shared/easybuild/software/AMUSE/2023.5.1/lib/python3.10/site-packages (from amuse-framework->amuse-fi) (68.1.2)
# Requirement already satisfied: setuptools-scm in /home/s3805352/.local/lib/python3.10/site-packages (from amuse-framework->amuse-fi) (7.1.0)
# Requirement already satisfied: pip>=19.0.0 in /cm/shared/easybuild/software/AMUSE/2023.5.1/lib/python3.10/site-packages (from amuse-framework->amuse-fi) (23.2.1)
# Requirement already satisfied: wheel>=0.32 in /cm/shared/easybuild/software/AMUSE/2023.5.1/lib/python3.10/site-packages (from amuse-framework->amuse-fi) (0.41.2)
# Requirement already satisfied: docutils>=0.6 in /cm/shared/easybuild/software/AMUSE/2023.5.1/lib/python3.10/site-packages (from amuse-framework->amuse-fi) (0.20.1)
# Requirement already satisfied: numpy>=1.2.2 in /cm/shared/easybuild/software/AMUSE/2023.5.1/lib/python3.10/site-packages (from amuse-framework->amuse-fi) (1.25.2)
# Requirement already satisfied: pytest>=4.0 in /cm/shared/easybuild/software/AMUSE/2023.5.1/lib/python3.10/site-packages (from amuse-framework->amuse-fi) (7.4.0)
# Requirement already satisfied: h5py>=1.1.0 in /cm/shared/easybuild/software/AMUSE/2023.5.1/lib/python3.10/site-packages (from amuse-framework->amuse-fi) (3.8.0)
# Requirement already satisfied: iniconfig in /cm/shared/easybuild/software/AMUSE/2023.5.1/lib/python3.10/site-packages (from pytest>=4.0->amuse-framework->amuse-fi) (2.0.0)
# Requirement already satisfied: packaging in /cm/shared/easybuild/software/AMUSE/2023.5.1/lib/python3.10/site-packages (from pytest>=4.0->amuse-framework->amuse-fi) (23.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /cm/shared/easybuild/software/AMUSE/2023.5.1/lib/python3.10/site-packages (from pytest>=4.0->amuse-framework->amuse-fi) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /cm/shared/easybuild/software/AMUSE/2023.5.1/lib/python3.10/site-packages (from pytest>=4.0->amuse-framework->amuse-fi) (1.1.3)
# Requirement already satisfied: tomli>=1.0.0 in /cm/shared/easybuild/software/AMUSE/2023.5.1/lib/python3.10/site-packages (from pytest>=4.0->amuse-framework->amuse-fi) (2.0.1)
# Requirement already satisfied: typing-extensions in /cm/shared/easybuild/software/AMUSE/2023.5.1/lib/python3.10/site-packages (from setuptools-scm->amuse-framework->amuse-fi) (4.7.1)
# Building wheels for collected packages: amuse-fi
#   Building wheel for amuse-fi (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Building wheel for amuse-fi (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [522 lines of output]
#       WARNING setuptools_scm.pyproject_reading toml section missing 'pyproject.toml does not contain a tool.setuptools_scm section'
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build/lib
#       creating build/lib/amuse
#       creating build/lib/amuse/community
#       creating build/lib/amuse/community/fi
#       copying src/amuse/community/fi/__init__.py -> build/lib/amuse/community/fi
#       copying src/amuse/community/fi/patch_globals_dot_h.py -> build/lib/amuse/community/fi
#       copying src/amuse/community/fi/interface.py -> build/lib/amuse/community/fi
#       copying src/amuse/community/fi/_version.py -> build/lib/amuse/community/fi
#       running build_codes
#       building libraries and community codes
#       build, for logging, see 'build.log'
#       creating build/temp.linux-x86_64-cpython-310
#       creating build/temp.linux-x86_64-cpython-310/codes
#       creating build/temp.linux-x86_64-cpython-310/codes/fi
#       copying src/amuse/community/fi/map_interface.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi
#       creating build/temp.linux-x86_64-cpython-310/codes/fi/data
#       copying src/amuse/community/fi/data/README.txt -> build/temp.linux-x86_64-cpython-310/codes/fi/data
#       creating build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/hk_124_12.halo -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/isoct_2_20_08.halo -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/isoct_3_30_1.halo -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/ssp_sca_z008.starmodel -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/isoct_6_40_025.halo -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/O.Hcool -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/ssp_sca_z0004.starmodel -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/ssp_sca_z0001.starmodel -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/ssp_sca_z02.starmodel -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/bct_18_06_10.halo -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/ssp_sca_z0004.starprop -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/Ne.cool -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/N.Hcool -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/ssp_salp_z008.starmodel -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/ssp_msca_z0001.starprop -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/hk_195_2.halo -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/ssp_salp_emp.starprop -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/ssp_salp_z0001.starmodel -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/nfwct_2_20_149.halo -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/He.cool -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/ssp_salp_z0001.starprop -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/ssp_sca_z10.starprop -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/ssp_sca_z004.starprop -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/nfw_2_10_0036.halo -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/ssp_sca_emp.starprop -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/bct_2_10_0045.halo -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/hk_102_2.halo -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/ssp_salp_z0004.starprop -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/ssp_salp_emp.starmodel -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/Fe.Hcool -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/ssp_sca_z004.starmodel -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/nfw_004_6.halo -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/readme -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/isoct_2_20_02.halo -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/isoct_7_40_00088 -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/isoct_7_40_00088.halo -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/ssp_salp_z004.starmodel -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/He.Hcool -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/ssp_salp_z004.starprop -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/ssp_msca_z008.starprop -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/ssp_msca_z0004.starprop -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/ssp_salp_z10.starmodel -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/ssp_sca_emp.starmodel -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/ssp_msca_z004.starprop -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/nfw_12_10_015.halo -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/burk_1.25.halo -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/ssp_salp_z0004.starmodel -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/Fe.cool -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/burk_1.8.halo -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/isoct_10_40_02.halo -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/hk_55_2.halo -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/isoct_2_20_005.halo -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/ssp_sca_z05.starmodel -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/ssp_salp_z10.starprop -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/ssp_msca_z10.starmodel -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/Si.cool -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/ssp_msca_z0001.starmodel -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/isoct_4_40_06.halo -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/isoct_10_40_02 -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/ssp_msca_z05.starprop -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/ssp_msca_emp.starmodel -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/isoct_04_20_32.halo -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/ssp_salp_z05.starmodel -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/O.cool -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/ssp_salp_z02.starmodel -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/ssp_sca_z0001.starprop -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/ssp_sca_z02.starprop -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/ssp_msca_z02.starmodel -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/hk_50_3.halo -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/isoct_2_20_01.halo -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/H.cool -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/burkct_4_20_04.halo -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/isoct_2_20_04.halo -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/H2.Hcool -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/ssp_sca_z10.starmodel -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/ssp_msca_z004.starmodel -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/H2.HH2cool -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/hk_96_2.halo -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/C.Hcool -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/ssp_msca_emp.starprop -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/hk_50_2.halo -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/isoct_6_40_04.halo -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/burkct_4_20_02.halo -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/H.Hcool -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/ssp_msca_z05.starmodel -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/isoct_2_40_1.halo -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/ssp_msca_z008.starmodel -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/ssp_salp_z02.starprop -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/ssp_sca_z05.starprop -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/isoct_2.6_40_0044.halo -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/hk_181_2.halo -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/ssp_msca_z10.starprop -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/bct_02_10.halo -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/Si.Hcool -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/bct_12_10_023.halo -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/ssp_salp_z008.starprop -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/ssp_msca_z02.starprop -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/extinctionlaw -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/ssp_sca_z008.starprop -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/Ne.Hcool -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/ssp_msca_z0004.starmodel -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/H2.H2cool -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/uvpol10_10 -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/hk_144_12.halo -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/C.cool -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/N.cool -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/burk_2.2.halo -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/data/input/ssp_salp_z05.starprop -> build/temp.linux-x86_64-cpython-310/codes/fi/data/input
#       copying src/amuse/community/fi/__init__.py -> build/temp.linux-x86_64-cpython-310/codes/fi
#       copying src/amuse/community/fi/interface.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi
#       copying src/amuse/community/fi/patch_globals_dot_h.py -> build/temp.linux-x86_64-cpython-310/codes/fi
#       creating build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/rgabe.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/init.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/gravity.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/search.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/readparam.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/heco.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/io2.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/rsimple.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/rgadget.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/map_helpers.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/sfh3.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/density.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/hicube.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/glfi.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/muse_interface.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/entdot.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/combine_simple.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/pt.h -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/muse_helpers.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/starprop.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/molecules.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/heating.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/sfh2.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/globals_template.h -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/makemapmod.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/hash.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/diagnostics.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/pt.c -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/snapviewer.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/buildtree.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/fthread.f -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/gravsum.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/muse_interface_gl.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/stepsystem.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/stellar.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/ptf77.c -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/mem.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/muse_io_stub.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/togabe2.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/fcco.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/varia.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/io.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/project.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/fuvflux.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/stars3d.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/sphray_io.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/coolcurve.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/blackhole.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/image -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/fi_viewer.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/update_tree.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/rgabe2.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/extern_dummy.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/feedback.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/fixedhalo.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/fi.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/io-old.f -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/sfinfo.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/treewalk.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/snapreader.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/buildnearlist.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/sfh.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/makemap.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/sort.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/timestep.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/pmgrav.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/elements.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/tosimple.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/ppread.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/extract.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/fftw3.f -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/util.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/clean.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/tosimplex.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/Makefile -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/ethstep.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/tidalsum.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/H2cool.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/muse_io2_stub.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/random.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/cooling.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/ionize.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/src/togabe.f90 -> build/temp.linux-x86_64-cpython-310/codes/fi/src
#       copying src/amuse/community/fi/interface.py -> build/temp.linux-x86_64-cpython-310/codes/fi
#       copying src/amuse/community/fi/_version.py -> build/temp.linux-x86_64-cpython-310/codes/fi
#       copying src/amuse/community/fi/README -> build/temp.linux-x86_64-cpython-310/codes/fi
#       copying src/amuse/community/fi/Makefile -> build/temp.linux-x86_64-cpython-310/codes/fi
#       [02:24:03] building fi
#       error in call, tail output:
#
#       x86_64
#
#       make: x86_64-conda-linux-gnu-gfortran: Command not found
#       make: Entering directory `/tmp/pip-install-jq4g_eq9/amuse-fi_6c910de366c04b0995445f1a8ab6dd1c/build/temp.linux-x86_64-cpython-310/codes/fi'
#       amusifier --type=f90 --needs-mpi=false interface.py FiInterface -o worker_code.f90
#       mkdir -p build
#       ln -s ../src/Makefile  build/Makefile
#       /cm/shared/easybuild/GenuineIntel/software/AMUSE/2023.5.1/bin/python3.1 ./patch_globals_dot_h.py --input=src/globals_template.h --output build/globals.h
#       make -C build amuse_interface FFLAGS="-I/tmp/pip-install-jq4g_eq9/amuse-fi_6c910de366c04b0995445f1a8ab6dd1c/build/temp.linux-x86_64-cpython-310/codes/fi/build -DNOMPI -fPIC" FC="x86_64-conda-linux-gnu-gfortran" VPATH=../src  F77FLAGS=""
#       make[1]: Entering directory `/tmp/pip-install-jq4g_eq9/amuse-fi_6c910de366c04b0995445f1a8ab6dd1c/build/temp.linux-x86_64-cpython-310/codes/fi/build'
#       x86_64-conda-linux-gnu-gfortran -I/tmp/pip-install-jq4g_eq9/amuse-fi_6c910de366c04b0995445f1a8ab6dd1c/build/temp.linux-x86_64-cpython-310/codes/fi/build -DNOMPI -fPIC -c -o mem.o ../src/mem.f90
#       make[1]: x86_64-conda-linux-gnu-gfortran: Command not found
#       make[1]: *** [mem.o] Error 127
#       make[1]: Leaving directory `/tmp/pip-install-jq4g_eq9/amuse-fi_6c910de366c04b0995445f1a8ab6dd1c/build/temp.linux-x86_64-cpython-310/codes/fi/build'
#       make: *** [build/libfi.a] Error 2
#       make: Leaving directory `/tmp/pip-install-jq4g_eq9/amuse-fi_6c910de366c04b0995445f1a8ab6dd1c/build/temp.linux-x86_64-cpython-310/codes/fi'
#
#       --------------------------------------------------------------------------------
#       error in call, tail output:
#
#       x86_64
#
#       make: x86_64-conda-linux-gnu-gfortran: Command not found
#       make: Entering directory `/tmp/pip-install-jq4g_eq9/amuse-fi_6c910de366c04b0995445f1a8ab6dd1c/build/temp.linux-x86_64-cpython-310/codes/fi'
#       amusifier --type=f90 --needs-mpi=false interface.py FiMapInterface -o map_worker_code.f90
#       mkdir -p build_map_mp
#       ln -s ../src/Makefile  build_map_mp/Makefile
#       /cm/shared/easybuild/GenuineIntel/software/AMUSE/2023.5.1/bin/python3.1 ./patch_globals_dot_h.py --input=src/globals_template.h --output build_map_mp/globals.h
#       make -C build_map_mp libmap.a FFLAGS="-I -DNOMPI -fPIC " FC="x86_64-conda-linux-gnu-gfortran" VPATH=../src  F77FLAGS=""
#       make[1]: Entering directory `/tmp/pip-install-jq4g_eq9/amuse-fi_6c910de366c04b0995445f1a8ab6dd1c/build/temp.linux-x86_64-cpython-310/codes/fi/build_map_mp'
#       x86_64-conda-linux-gnu-gfortran -I -DNOMPI -fPIC  -c -o makemapmod.o ../src/makemapmod.f90
#       make[1]: x86_64-conda-linux-gnu-gfortran: Command not found
#       make[1]: *** [makemapmod.o] Error 127
#       make[1]: Leaving directory `/tmp/pip-install-jq4g_eq9/amuse-fi_6c910de366c04b0995445f1a8ab6dd1c/build/temp.linux-x86_64-cpython-310/codes/fi/build_map_mp'
#       make: *** [build_map_mp/libmap.a] Error 2
#       make: Leaving directory `/tmp/pip-install-jq4g_eq9/amuse-fi_6c910de366c04b0995445f1a8ab6dd1c/build/temp.linux-x86_64-cpython-310/codes/fi'
#
#       --------------------------------------------------------------------------------
#       error in call, tail output:
#
#       x86_64
#
#       make: x86_64-conda-linux-gnu-gfortran: Command not found
#       make: Entering directory `/tmp/pip-install-jq4g_eq9/amuse-fi_6c910de366c04b0995445f1a8ab6dd1c/build/temp.linux-x86_64-cpython-310/codes/fi'
#       mkdir -p build_periodic
#       ln -s ../src/Makefile build_periodic/Makefile
#       /cm/shared/easybuild/GenuineIntel/software/AMUSE/2023.5.1/bin/python3.1 ./patch_globals_dot_h.py --periodic --input=src/globals_template.h --output build_periodic/globals.h
#       make -C build_periodic amuse_interface FFLAGS="-I/tmp/pip-install-jq4g_eq9/amuse-fi_6c910de366c04b0995445f1a8ab6dd1c/build/temp.linux-x86_64-cpython-310/codes/fi/build_periodic -DNOMPI -fPIC" FC="x86_64-conda-linux-gnu-gfortran" VPATH=../src   F77FLAGS=""
#       make[1]: Entering directory `/tmp/pip-install-jq4g_eq9/amuse-fi_6c910de366c04b0995445f1a8ab6dd1c/build/temp.linux-x86_64-cpython-310/codes/fi/build_periodic'
#       x86_64-conda-linux-gnu-gfortran -I/tmp/pip-install-jq4g_eq9/amuse-fi_6c910de366c04b0995445f1a8ab6dd1c/build/temp.linux-x86_64-cpython-310/codes/fi/build_periodic -DNOMPI -fPIC -c -o mem.o ../src/mem.f90
#       make[1]: x86_64-conda-linux-gnu-gfortran: Command not found
#       make[1]: *** [mem.o] Error 127
#       make[1]: Leaving directory `/tmp/pip-install-jq4g_eq9/amuse-fi_6c910de366c04b0995445f1a8ab6dd1c/build/temp.linux-x86_64-cpython-310/codes/fi/build_periodic'
#       make: *** [build_periodic/libfi.a] Error 2
#       make: Leaving directory `/tmp/pip-install-jq4g_eq9/amuse-fi_6c910de366c04b0995445f1a8ab6dd1c/build/temp.linux-x86_64-cpython-310/codes/fi'
#
#       --------------------------------------------------------------------------------
#       error in call, tail output:
#
#       x86_64
#
#       make: x86_64-conda-linux-gnu-gfortran: Command not found
#       make: Entering directory `/tmp/pip-install-jq4g_eq9/amuse-fi_6c910de366c04b0995445f1a8ab6dd1c/build/temp.linux-x86_64-cpython-310/codes/fi'
#       amusifier --type=f90 interface.py GlFiInterface -o worker_code-gl.f90
#       /cm/shared/easybuild/GenuineIntel/software/AMUSE/2023.5.1/bin/python3.1 ./patch_globals_dot_h.py --input=src/globals_template.h --output build/globals.h
#       make -C build amuse_interface FFLAGS="-I/tmp/pip-install-jq4g_eq9/amuse-fi_6c910de366c04b0995445f1a8ab6dd1c/build/temp.linux-x86_64-cpython-310/codes/fi/build -DNOMPI -fPIC" FC="x86_64-conda-linux-gnu-gfortran" VPATH=../src  F77FLAGS=""
#       make[1]: Entering directory `/tmp/pip-install-jq4g_eq9/amuse-fi_6c910de366c04b0995445f1a8ab6dd1c/build/temp.linux-x86_64-cpython-310/codes/fi/build'
#       x86_64-conda-linux-gnu-gfortran -I/tmp/pip-install-jq4g_eq9/amuse-fi_6c910de366c04b0995445f1a8ab6dd1c/build/temp.linux-x86_64-cpython-310/codes/fi/build -DNOMPI -fPIC -c -o mem.o ../src/mem.f90
#       make[1]: x86_64-conda-linux-gnu-gfortran: Command not found
#       make[1]: *** [mem.o] Error 127
#       make[1]: Leaving directory `/tmp/pip-install-jq4g_eq9/amuse-fi_6c910de366c04b0995445f1a8ab6dd1c/build/temp.linux-x86_64-cpython-310/codes/fi/build'
#       make: *** [build/libfi.a] Error 2
#       make: Leaving directory `/tmp/pip-install-jq4g_eq9/amuse-fi_6c910de366c04b0995445f1a8ab6dd1c/build/temp.linux-x86_64-cpython-310/codes/fi'
#
#       --------------------------------------------------------------------------------
#       error in call, tail output:
#
#       x86_64
#
#       make: x86_64-conda-linux-gnu-gfortran: Command not found
#       make: Entering directory `/tmp/pip-install-jq4g_eq9/amuse-fi_6c910de366c04b0995445f1a8ab6dd1c/build/temp.linux-x86_64-cpython-310/codes/fi'
#       mkdir -p build_map
#       ln -s ../src/Makefile  build_map/Makefile
#       /cm/shared/easybuild/GenuineIntel/software/AMUSE/2023.5.1/bin/python3.1 ./patch_globals_dot_h.py --input=src/globals_template.h --output build_map/globals.h
#       make -C build_map libmap.a FFLAGS="-I/tmp/pip-install-jq4g_eq9/amuse-fi_6c910de366c04b0995445f1a8ab6dd1c/build/temp.linux-x86_64-cpython-310/codes/fi/build_map -DNOMPI -fPIC" FC="x86_64-conda-linux-gnu-gfortran" VPATH=../src  F77FLAGS=""
#       make[1]: Entering directory `/tmp/pip-install-jq4g_eq9/amuse-fi_6c910de366c04b0995445f1a8ab6dd1c/build/temp.linux-x86_64-cpython-310/codes/fi/build_map'
#       x86_64-conda-linux-gnu-gfortran -I/tmp/pip-install-jq4g_eq9/amuse-fi_6c910de366c04b0995445f1a8ab6dd1c/build/temp.linux-x86_64-cpython-310/codes/fi/build_map -DNOMPI -fPIC -c -o makemapmod.o ../src/makemapmod.f90
#       make[1]: x86_64-conda-linux-gnu-gfortran: Command not found
#       make[1]: *** [makemapmod.o] Error 127
#       make[1]: Leaving directory `/tmp/pip-install-jq4g_eq9/amuse-fi_6c910de366c04b0995445f1a8ab6dd1c/build/temp.linux-x86_64-cpython-310/codes/fi/build_map'
#       make: *** [build_map/libmap.a] Error 2
#       make: Leaving directory `/tmp/pip-install-jq4g_eq9/amuse-fi_6c910de366c04b0995445f1a8ab6dd1c/build/temp.linux-x86_64-cpython-310/codes/fi'
#
#       --------------------------------------------------------------------------------
#       error in call, tail output:
#
#       x86_64
#
#       make: x86_64-conda-linux-gnu-gfortran: Command not found
#       make: Entering directory `/tmp/pip-install-jq4g_eq9/amuse-fi_6c910de366c04b0995445f1a8ab6dd1c/build/temp.linux-x86_64-cpython-310/codes/fi'
#       /cm/shared/easybuild/GenuineIntel/software/AMUSE/2023.5.1/bin/python3.1 ./patch_globals_dot_h.py --periodic --input=src/globals_template.h --output build_periodic/globals.h
#       make -C build_periodic amuse_interface FFLAGS="-I/tmp/pip-install-jq4g_eq9/amuse-fi_6c910de366c04b0995445f1a8ab6dd1c/build/temp.linux-x86_64-cpython-310/codes/fi/build_periodic -DNOMPI -fPIC" FC="x86_64-conda-linux-gnu-gfortran" VPATH=../src   F77FLAGS=""
#       make[1]: Entering directory `/tmp/pip-install-jq4g_eq9/amuse-fi_6c910de366c04b0995445f1a8ab6dd1c/build/temp.linux-x86_64-cpython-310/codes/fi/build_periodic'
#       x86_64-conda-linux-gnu-gfortran -I/tmp/pip-install-jq4g_eq9/amuse-fi_6c910de366c04b0995445f1a8ab6dd1c/build/temp.linux-x86_64-cpython-310/codes/fi/build_periodic -DNOMPI -fPIC -c -o mem.o ../src/mem.f90
#       make[1]: x86_64-conda-linux-gnu-gfortran: Command not found
#       make[1]: *** [mem.o] Error 127
#       make[1]: Leaving directory `/tmp/pip-install-jq4g_eq9/amuse-fi_6c910de366c04b0995445f1a8ab6dd1c/build/temp.linux-x86_64-cpython-310/codes/fi/build_periodic'
#       make: *** [build_periodic/libfi.a] Error 2
#       make: Leaving directory `/tmp/pip-install-jq4g_eq9/amuse-fi_6c910de366c04b0995445f1a8ab6dd1c/build/temp.linux-x86_64-cpython-310/codes/fi'
#
#       --------------------------------------------------------------------------------
#       error in call, tail output:
#
#       x86_64
#
#       make: x86_64-conda-linux-gnu-gfortran: Command not found
#       make: Entering directory `/tmp/pip-install-jq4g_eq9/amuse-fi_6c910de366c04b0995445f1a8ab6dd1c/build/temp.linux-x86_64-cpython-310/codes/fi'
#       mkdir -p build_mp
#       ln -s ../src/Makefile build_mp/Makefile
#       /cm/shared/easybuild/GenuineIntel/software/AMUSE/2023.5.1/bin/python3.1 ./patch_globals_dot_h.py --input=src/globals_template.h --output build_mp/globals.h
#       make -C build_mp amuse_interface FFLAGS="-I/tmp/pip-install-jq4g_eq9/amuse-fi_6c910de366c04b0995445f1a8ab6dd1c/build/temp.linux-x86_64-cpython-310/codes/fi/build_mp -DNOMPI -fPIC " FC="x86_64-conda-linux-gnu-gfortran" VPATH=../src   F77FLAGS=" "
#       make[1]: Entering directory `/tmp/pip-install-jq4g_eq9/amuse-fi_6c910de366c04b0995445f1a8ab6dd1c/build/temp.linux-x86_64-cpython-310/codes/fi/build_mp'
#       x86_64-conda-linux-gnu-gfortran -I/tmp/pip-install-jq4g_eq9/amuse-fi_6c910de366c04b0995445f1a8ab6dd1c/build/temp.linux-x86_64-cpython-310/codes/fi/build_mp -DNOMPI -fPIC  -c -o mem.o ../src/mem.f90
#       make[1]: x86_64-conda-linux-gnu-gfortran: Command not found
#       make[1]: *** [mem.o] Error 127
#       make[1]: Leaving directory `/tmp/pip-install-jq4g_eq9/amuse-fi_6c910de366c04b0995445f1a8ab6dd1c/build/temp.linux-x86_64-cpython-310/codes/fi/build_mp'
#       make: *** [build_mp/libfi.a] Error 2
#       make: Leaving directory `/tmp/pip-install-jq4g_eq9/amuse-fi_6c910de366c04b0995445f1a8ab6dd1c/build/temp.linux-x86_64-cpython-310/codes/fi'
#
#       --------------------------------------------------------------------------------
#       will copy worker: src/amuse/community/fi
#       fi
#       creating build/lib/amuse/community/fi/data
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/README.txt -> build/lib/amuse/community/fi/data
#       creating build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/hk_124_12.halo -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/isoct_2_20_08.halo -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/isoct_3_30_1.halo -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/ssp_sca_z008.starmodel -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/isoct_6_40_025.halo -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/O.Hcool -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/ssp_sca_z0004.starmodel -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/ssp_sca_z0001.starmodel -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/ssp_sca_z02.starmodel -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/bct_18_06_10.halo -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/ssp_sca_z0004.starprop -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/Ne.cool -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/N.Hcool -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/ssp_salp_z008.starmodel -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/ssp_msca_z0001.starprop -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/hk_195_2.halo -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/ssp_salp_emp.starprop -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/ssp_salp_z0001.starmodel -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/nfwct_2_20_149.halo -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/He.cool -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/ssp_salp_z0001.starprop -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/ssp_sca_z10.starprop -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/ssp_sca_z004.starprop -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/nfw_2_10_0036.halo -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/ssp_sca_emp.starprop -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/bct_2_10_0045.halo -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/hk_102_2.halo -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/ssp_salp_z0004.starprop -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/ssp_salp_emp.starmodel -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/Fe.Hcool -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/ssp_sca_z004.starmodel -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/nfw_004_6.halo -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/readme -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/isoct_2_20_02.halo -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/isoct_7_40_00088 -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/isoct_7_40_00088.halo -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/ssp_salp_z004.starmodel -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/He.Hcool -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/ssp_salp_z004.starprop -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/ssp_msca_z008.starprop -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/ssp_msca_z0004.starprop -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/ssp_salp_z10.starmodel -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/ssp_sca_emp.starmodel -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/ssp_msca_z004.starprop -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/nfw_12_10_015.halo -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/burk_1.25.halo -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/ssp_salp_z0004.starmodel -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/Fe.cool -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/burk_1.8.halo -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/isoct_10_40_02.halo -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/hk_55_2.halo -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/isoct_2_20_005.halo -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/ssp_sca_z05.starmodel -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/ssp_salp_z10.starprop -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/ssp_msca_z10.starmodel -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/Si.cool -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/ssp_msca_z0001.starmodel -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/isoct_4_40_06.halo -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/isoct_10_40_02 -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/ssp_msca_z05.starprop -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/ssp_msca_emp.starmodel -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/isoct_04_20_32.halo -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/ssp_salp_z05.starmodel -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/O.cool -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/ssp_salp_z02.starmodel -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/ssp_sca_z0001.starprop -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/ssp_sca_z02.starprop -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/ssp_msca_z02.starmodel -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/hk_50_3.halo -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/isoct_2_20_01.halo -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/H.cool -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/burkct_4_20_04.halo -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/isoct_2_20_04.halo -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/H2.Hcool -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/ssp_sca_z10.starmodel -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/ssp_msca_z004.starmodel -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/H2.HH2cool -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/hk_96_2.halo -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/C.Hcool -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/ssp_msca_emp.starprop -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/hk_50_2.halo -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/isoct_6_40_04.halo -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/burkct_4_20_02.halo -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/H.Hcool -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/ssp_msca_z05.starmodel -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/isoct_2_40_1.halo -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/ssp_msca_z008.starmodel -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/ssp_salp_z02.starprop -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/ssp_sca_z05.starprop -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/isoct_2.6_40_0044.halo -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/hk_181_2.halo -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/ssp_msca_z10.starprop -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/bct_02_10.halo -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/Si.Hcool -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/bct_12_10_023.halo -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/ssp_salp_z008.starprop -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/ssp_msca_z02.starprop -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/extinctionlaw -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/ssp_sca_z008.starprop -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/Ne.Hcool -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/ssp_msca_z0004.starmodel -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/H2.H2cool -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/uvpol10_10 -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/hk_144_12.halo -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/C.cool -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/N.cool -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/burk_2.2.halo -> build/lib/amuse/community/fi/data/input
#       copying build/temp.linux-x86_64-cpython-310/codes/fi/data/input/ssp_salp_z05.starprop -> build/lib/amuse/community/fi/data/input
#       Community codes not built (because of errors/ missing libraries):
#       ================================================================================
#        * fi
#       Optional builds skipped, need special libraries:
#        * fi - map_mp, periodic, gl, map, periodic_gl, mp
#       ================================================================================
#       0 out of 1 codes built, 0 out of 0 libraries built
#       Traceback (most recent call last):
#         File "/cm/shared/easybuild/GenuineIntel/software/AMUSE/2023.5.1/lib/python3.10/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 353, in <module>
#           main()
#         File "/cm/shared/easybuild/GenuineIntel/software/AMUSE/2023.5.1/lib/python3.10/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 335, in main
#           json_out['return_val'] = hook(**hook_input['kwargs'])
#         File "/cm/shared/easybuild/GenuineIntel/software/AMUSE/2023.5.1/lib/python3.10/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 251, in build_wheel
#           return _build_backend().build_wheel(wheel_directory, config_settings,
#         File "/tmp/pip-build-env-xux1xx6z/overlay/lib/python3.10/site-packages/setuptools/build_meta.py", line 404, in build_wheel
#           return self._build_with_temp_dir(
#         File "/tmp/pip-build-env-xux1xx6z/overlay/lib/python3.10/site-packages/setuptools/build_meta.py", line 389, in _build_with_temp_dir
#           self.run_setup()
#         File "/tmp/pip-build-env-xux1xx6z/overlay/lib/python3.10/site-packages/setuptools/build_meta.py", line 480, in run_setup
#           super(_BuildMetaLegacyBackend, self).run_setup(setup_script=setup_script)
#         File "/tmp/pip-build-env-xux1xx6z/overlay/lib/python3.10/site-packages/setuptools/build_meta.py", line 311, in run_setup
#           exec(code, locals())
#         File "<string>", line 43, in <module>
#         File "/tmp/pip-build-env-xux1xx6z/overlay/lib/python3.10/site-packages/setuptools/__init__.py", line 103, in setup
#           return distutils.core.setup(**attrs)
#         File "/tmp/pip-build-env-xux1xx6z/overlay/lib/python3.10/site-packages/setuptools/_distutils/core.py", line 185, in setup
#           return run_commands(dist)
#         File "/tmp/pip-build-env-xux1xx6z/overlay/lib/python3.10/site-packages/setuptools/_distutils/core.py", line 201, in run_commands
#           dist.run_commands()
#         File "/tmp/pip-build-env-xux1xx6z/overlay/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 969, in run_commands
#           self.run_command(cmd)
#         File "/tmp/pip-build-env-xux1xx6z/overlay/lib/python3.10/site-packages/setuptools/dist.py", line 963, in run_command
#           super().run_command(command)
#         File "/tmp/pip-build-env-xux1xx6z/overlay/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "/tmp/pip-build-env-xux1xx6z/overlay/lib/python3.10/site-packages/wheel/bdist_wheel.py", line 368, in run
#           self.run_command("build")
#         File "/tmp/pip-build-env-xux1xx6z/overlay/lib/python3.10/site-packages/setuptools/_distutils/cmd.py", line 318, in run_command
#           self.distribution.run_command(command)
#         File "/tmp/pip-build-env-xux1xx6z/overlay/lib/python3.10/site-packages/setuptools/dist.py", line 963, in run_command
#           super().run_command(command)
#         File "/tmp/pip-build-env-xux1xx6z/overlay/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "/tmp/pip-build-env-xux1xx6z/overlay/lib/python3.10/site-packages/setuptools/_distutils/command/build.py", line 131, in run
#           self.run_command(cmd_name)
#         File "/tmp/pip-build-env-xux1xx6z/overlay/lib/python3.10/site-packages/setuptools/_distutils/cmd.py", line 318, in run_command
#           self.distribution.run_command(command)
#         File "/tmp/pip-build-env-xux1xx6z/overlay/lib/python3.10/site-packages/setuptools/dist.py", line 963, in run_command
#           super().run_command(command)
#         File "/tmp/pip-build-env-xux1xx6z/overlay/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "/tmp/pip-install-jq4g_eq9/amuse-fi_6c910de366c04b0995445f1a8ab6dd1c/support/setup_codes.py", line 1101, in run
#           raise Exception("No succesful builds detected. Aborting.")
#       Exception: No succesful builds detected. Aborting.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for amuse-fi
# Failed to build amuse-fi
# ERROR: Could not build wheels for amuse-fi, which is required to install pyproject.toml-based projects
# Note: you may need to restart the kernel to use updated packages.

# %%
tot_cloud_mass = 4/3 *units.constants.pi * (15 | units.pc)**3 * ( 2.3 | units.amu * 10 / (units.cm**3))
print(tot_cloud_mass.value_in(units.MSun))

#Assmuing a pure molecular hydrogen cloud, with typical density around 85 molecules per cm^-3, calculate the approximate cloud mass based on
#cloud size. 50 pc is selected for a small GC of only 100 stars. 

# %%
# initialise and evolve the MC particle set
init_cloud, init_cloud_converter  = make_molecular_cloud(N_cloud = 400_000,
                                                         M_cloud = 20_000 | units.MSun,
                                                         R_cloud = 15 | units.pc,
                                                         seed = 1312)

init_cloud, density_map = evolve_molecular_cloud(init_cloud, 
                                                    init_cloud_converter, 
                                                    t_end = 2 | units.Myr, 
                                                    dt = 0.2 | units.Myr, 
                                                    seed = 1312)

print("Mean density of the moelcular cloud", np.mean(init_cloud.density))
#%%
def hydro_code(Code, dt, converter, particles, seed):
    '''
    This function contains the parameters we want to initialise the 
    hydro code with. (hard Coded)
    '''
    
    np.random.seed(seed)

    hydro = Code(converter)
    hydro.parameters.use_hydro_flag = True # Hydrodynamics flag. True means:
                            # SPH hydro included, False means: gravity only.
    hydro.parameters.gamma = 1 # gas polytropic index (1.6666667)
                        # (default value:1.6666667). In this case-> Ideal Gas   
    hydro.parameters.timestep = dt
    hydro.parameters.eps_is_h_flag = True # Default value
    hydro.parameters.radiation_flag = False # turns off radiatiative cooling/heat.
    hydro.parameters.isothermal_flag = True  # Isothermal flag. True means:
                                            # isothermal gas (requires integrate_entropy_flag == False)
    hydro.parameters.integrate_entropy_flag = False #True means: integrate
                                                     # entropy, else: internal energy. 
    hydro.gas_particles.add_particles(particles) # add the particles
   
    return hydro    

def bondi_radius(stellar_mass):
    sound_speed = 0.2 | units.kms
    R = 2 * units.constants.G * stellar_mass /(sound_speed **2)

    return R

def bondi_accretion_rate(rho,v,r):
    dM = units.constants.pi * (r**2) * rho * v

    return dM


def make_cluster_with_vinit(velocity):
    star_cluster = make_globular_cluster(star_count = 200,
                                        imf = "kroupa", 
                                        radius = 4 | units.pc,
                                        metallicity = 0.002, 
                                        age = 10 | units.Gyr, 
                                        seed = 2804)

    star_cluster.position +=  (-1.0, 0, 0) * (30 | units.pc)
    star_cluster.velocity += (1.0, 0, 0) * (velocity| units.kms)

    converter_cluster = nbody_system.nbody_to_si(star_cluster.mass.sum(), 
                                    star_cluster.position.sum())
 
    return star_cluster,converter_cluster





def AMUSE_bridge_initialization(star_cluster,converter_cluster):
    #initiate the gravity code with sink particles
    gravity_code = Bhtree(converter_cluster)
    sinks = new_sink_particles(star_cluster)

    gravity_code.particles.add_particles(sinks)

    # #start the hydro code for the gas
    converter_cloud = init_cloud_converter
    particles_cloud = init_cloud.copy()
    hydro_cloud = hydro_code(Code = Fi, dt = 0.1 | units.Myr,
                            converter = converter_cloud,
                            particles = particles_cloud,
                            seed = 1312)


    channel = {"to_sinks": gravity_code.particles.new_channel_to(sinks),
                "from_sinks": sinks.new_channel_to(gravity_code.particles),
                "to_cloud": hydro_cloud.gas_particles.new_channel_to(particles_cloud),
                "from_cloud": particles_cloud.new_channel_to(hydro_cloud.gas_particles)}


    gravhydrobridge = bridge.Bridge(use_threading = False)
    gravhydrobridge.add_system(gravity_code, (hydro_cloud,) )
    gravhydrobridge.add_system(hydro_cloud, (gravity_code,) )
    gravhydrobridge.timestep = 0.1 | units.Myr

    return gravhydrobridge,sinks,channel,particles_cloud,gravity_code,hydro_cloud


def let_them_collide(directory_path,t_end,dt,sinks,gravhydrobridge,channel,particles_cloud,gravity_code,hydro_cloud):
    t_end = t_end | units.Myr
    model_time = 0 | units.Myr
    dt = dt | units.Myr

    sinks_mass_snapshots = []
    current_velocity = sum(sinks.vx.value_in(units.kms))/len(sinks.vx)
    print("Colliding with cluster velocity", current_velocity)

    while model_time < t_end:
        
        # define the accreting radius of the sinks particle based on its Bondi radius
        # IMPORTANT: the mass changes after each accretion event
        sinks.sink_radius = bondi_radius(sinks.mass).in_(units.pc)

        print("Largest sink radius", max(sinks.sink_radius).in_(units.pc))

        print("Pre accretion cluster mass", sinks.mass.sum())
        
        model_time += dt
        model_time = model_time.round(1)
        # evolve the gravity and hydro codes through our bridge
        gravhydrobridge.evolve_model(model_time)


        # update channels (copy over from the codes.particles to the particle sets)
        channel["to_sinks"].copy()
        channel["to_cloud"].copy()

        print("Sinks in progress at", model_time.value_in(units.Myr), " Myr.")
        # add the acretted mass to the sinks's total mass
        sinks.accrete(particles_cloud)

        # update channels (copy the information from the particle set to the gravity code)
        channel["from_sinks"].copy()
        channel["from_cloud"].copy()

        # save the total mass of each step
        sinks_mass_snapshots.append(sinks.mass.value_in(units.MSun))

        print("Post accretion cluster mass", sinks.mass.sum().in_(units.MSun))
        print(len(particles_cloud.mass), "number of cloud particles now")


        plt.scatter(particles_cloud.x.value_in(units.pc), particles_cloud.y.value_in(units.pc), s = 1)
        plt.scatter(sinks.x.value_in(units.pc), sinks.y.value_in(units.pc), c = 'red', s = 5)
        plt.title("Molecular cloud at time = " + model_time.as_string_in(units.Myr))
        plt.xlabel("x [pc]")
        plt.ylabel("y [pc]")
        plt.savefig(os.path.join(directory_path, f"at time_{model_time.value_in(units.Myr)}.png"))
        plt.close()


    mass_difference = sinks_mass_snapshots[-1] - sinks_mass_snapshots[0]

    # Save the list to a text file
    with open(os.path.join(directory_path, \
                           f"Sink mass_{current_velocity}.txt"), 'w') as file:
        for sublist in sinks_mass_snapshots:
            line = ' '.join(map(str, sublist))  # Convert sublist to a space-separated string
            file.write(line + '\n')

    print("Mass snapshots saved.")

    plt.plot(sinks_mass_snapshots)
    plt.xlabel("time [Myr]")
    plt.ylabel("mass [Msun]")
    plt.show()
    plt.savefig(os.path.join(directory_path, f"Sink mass_{current_velocity}.png"))
    plt.close()

    plt.hist(mass_difference, bins  = 30)
    plt.savefig(os.path.join(directory_path, f"Accreted mass hist_{current_velocity}.png"))
    plt.close()

    gravity_code.stop()
    hydro_cloud.stop()
    gravhydrobridge.stop()

#%%

# %%
velocity = np.linspace(15,70,10,dtype=int)

for i in range (len(velocity)):
    v = velocity[i]
    print("Starting with cluster velocity",v)
    star_cluster,converter_cluster = make_cluster_with_vinit(v)
    gravhydrobridge,sinks,channel,particles_cloud,gravity_code,\
        hydro_cloud = AMUSE_bridge_initialization(star_cluster,converter_cluster)
    
    path = '../results/'
    variable_name = v
    directory_path = os.path.join(path, str(variable_name))
    os.makedirs(directory_path, exist_ok=True)

    if __name__ == "__main__":
        start_time = time()
        date_time = datetime.utcfromtimestamp(start_time).strftime('%Y-%m-%d_%H-%M-%S')
        print("Collision started on {}".format(socket.gethostname()),f"at time {format(date_time)}")
        
        let_them_collide(directory_path,2,0.1,sinks,gravhydrobridge,channel,particles_cloud,gravity_code,hydro_cloud)

        print("Collision finished (running time: {0:.1f}s)".format(time() - start_time))
# %%
